# %%
import numpy as np
import os
import matplotlib.pyplot as plt
import nibabel
import pydicom
import dicom2nifti

# %%
#Get folders list
data_path = 'D:/AI_Project/2018_training/MICCAI_BraTS_2018_Data_Training/HGG/'
folders = os.listdir(data_path) 

# Traverse all the folders
for folder in folders:
    dicom_folder = data_path + folder
    nii_folder = data_path + 'nii_'+ folder
    os.mkdir(nii_folder) #Create folder to store the .nii files
    dicom2nifti.convert_directory(dicom_folder, nii_folder, compression= False) #Default compression= True
    print(folder + " has been converted.")


print("Conversion finished.")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_32560\416230733.py in <module>
#       7     dicom_folder = data_path + folder
#       8     nii_folder = data_path + 'nii_'+ folder
# ----> 9     os.mkdir(nii_folder) #Create folder to store the .nii files
#      10     dicom2nifti.convert_directory(dicom_folder, nii_folder, compression= False) #Default compression= True
#      11     print(folder + " has been converted.")
#
# FileExistsError: [WinError 183] 當檔案已存在時，無法建立該檔案。: 'D:/AI_Project/2018_training/MICCAI_BraTS_2018_Data_Training/HGG/nii_Brats18_2013_10_1'

# %%
t1 = nibabel.load(data_path+'Brats18_2013_2_1/Brats18_2013_2_1_t1.nii').get_fdata() #Don't forget .get_fdata()

#Rotate and transpose to get sagittal plane 
t1 = np.rot90(t1)
t1 = np.transpose(t1,(0,2,1))
t1 = np.rot90(t1)
print(t1.shape)
plt.imshow(t1[:,:,100], cmap='gray')
plt.show()
# Out:
# (155, 240, 240)

# %%
t1 = nibabel.load(data_path+'Brats18_2013_2_1/Brats18_2013_2_1_t1.nii').get_fdata() #Don't forget .get_fdata()
print(t1.shape) 
plt.imshow(t1[:,:,100], cmap='gray')
plt.show()
# Out:
# (240, 240, 155)

# %%
t1ce = nibabel.load(data_path+'Brats18_2013_2_1/Brats18_2013_2_1_t1ce.nii').get_fdata() #Don't forget .get_fdata()
print(t1ce.shape)
plt.imshow(t1ce[:,:,100], cmap='gray')
plt.show()
# Out:
# (240, 240, 155)

# %%
seg = nibabel.load(data_path+'Brats18_2013_2_1/Brats18_2013_2_1_seg.nii').get_fdata() #Don't forget .get_fdata()
print(seg.shape)
plt.imshow(seg[:,:,100], cmap='gray')
plt.show()
# Out:
# (240, 240, 155)

# %%
flair = nibabel.load(data_path+'Brats18_2013_2_1/Brats18_2013_2_1_flair.nii').get_fdata() #Don't forget .get_fdata()
print(flair.shape)
plt.imshow(flair[:,:,100], cmap='gray')
plt.show()
# Out:
# (240, 240, 155)

# %%
t2 = nibabel.load(data_path+'Brats18_2013_2_1/Brats18_2013_2_1_t2.nii').get_fdata() #Don't forget .get_fdata()
print(t2.shape)
plt.imshow(t2[:,:,100], cmap='gray')
plt.show()
# Out:
# (240, 240, 155)

# %%
#2018 HGG
plt.figure(figsize=(9,6))
plt.subplot(2,3,1)
t1 = nibabel.load(data_path+'Brats18_2013_2_1/Brats18_2013_2_1_t1.nii').get_fdata() #Don't forget .get_fdata()
print(t1.shape)
plt.title('T1')
plt.imshow(t1[:,:,100], cmap='gray')

plt.subplot(2,3,2)
t1ce = nibabel.load(data_path+'Brats18_2013_2_1/Brats18_2013_2_1_t1ce.nii').get_fdata() #Don't forget .get_fdata()
print(t1ce.shape)
plt.title('T1ce')
plt.imshow(t1ce[:,:,100], cmap='gray')

plt.subplot(2,3,3)
seg = nibabel.load(data_path+'Brats18_2013_2_1/Brats18_2013_2_1_seg.nii').get_fdata() #Don't forget .get_fdata()
print(seg.shape)
plt.title('Seg')
plt.imshow(seg[:,:,100], cmap='gray')

plt.subplot(2,3,4)
flair = nibabel.load(data_path+'Brats18_2013_2_1/Brats18_2013_2_1_flair.nii').get_fdata() #Don't forget .get_fdata()
print(flair.shape)
plt.title('FLAIR')
plt.imshow(flair[:,:,100], cmap='gray')

plt.subplot(2,3,5)
t2 = nibabel.load(data_path+'Brats18_2013_2_1/Brats18_2013_2_1_t2.nii').get_fdata() #Don't forget .get_fdata()
print(t2.shape)
plt.title('T2')
plt.imshow(t2[:,:,100], cmap='gray')
# Out:
# (240, 240, 155)
# (240, 240, 155)
# (240, 240, 155)
# (240, 240, 155)
# (240, 240, 155)

# %%
#Get folders list
data_path1 = 'D:/AI_Project/2018_training/MICCAI_BraTS_2018_Data_Training/LGG/'
folders1 = os.listdir(data_path1) 

# Traverse all the folders
for folder1 in folders1:
    dicom_folder1 = data_path1 + folder1
    nii_folder1 = data_path1 + 'nii_'+ folder1
    os.mkdir(nii_folder1) #Create folder to store the .nii files
    dicom2nifti.convert_directory(dicom_folder1, nii_folder1, compression= False) #Default compression= True
    print(folder1 + " has been converted.")


print("Conversion finished.")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_32560\3600786471.py in <module>
#       7     dicom_folder1 = data_path1 + folder1
#       8     nii_folder1 = data_path1 + 'nii_'+ folder1
# ----> 9     os.mkdir(nii_folder1) #Create folder to store the .nii files
#      10     dicom2nifti.convert_directory(dicom_folder1, nii_folder1, compression= False) #Default compression= True
#      11     print(folder1 + " has been converted.")
#
# FileExistsError: [WinError 183] 當檔案已存在時，無法建立該檔案。: 'D:/AI_Project/2018_training/MICCAI_BraTS_2018_Data_Training/LGG/nii_Brats18_2013_0_1'

# %%
#2018 LGG
plt.subplot(2,3,1)
t1 = nibabel.load(data_path1+'Brats18_2013_0_1/Brats18_2013_0_1_t1.nii').get_fdata() #Don't forget .get_fdata()
print(t1.shape)
plt.imshow(t1[:,:,100], cmap='gray')

plt.subplot(2,3,2)
t1ce = nibabel.load(data_path1+'Brats18_2013_0_1/Brats18_2013_0_1_t1ce.nii').get_fdata() #Don't forget .get_fdata()
print(t1ce.shape)
plt.imshow(t1ce[:,:,100], cmap='gray')

plt.subplot(2,3,3)
seg = nibabel.load(data_path1+'Brats18_2013_0_1/Brats18_2013_0_1_seg.nii').get_fdata() #Don't forget .get_fdata()
print(seg.shape)
plt.imshow(seg[:,:,100], cmap='gray')

plt.subplot(2,3,4)
flair = nibabel.load(data_path1+'Brats18_2013_0_1/Brats18_2013_0_1_flair.nii').get_fdata() #Don't forget .get_fdata()
print(flair.shape)
plt.imshow(flair[:,:,100], cmap='gray')

plt.subplot(2,3,5)
t2 = nibabel.load(data_path1+'Brats18_2013_0_1/Brats18_2013_0_1_t2.nii').get_fdata() #Don't forget .get_fdata()
print(t2.shape)
plt.imshow(t2[:,:,100], cmap='gray')
# Out:
# (240, 240, 155)
# (240, 240, 155)
# (240, 240, 155)
# (240, 240, 155)
# (240, 240, 155)

# %%
#2018 LGG
plt.figure(figsize=(9,6))

plt.subplot(2,3,1)
t1 = nibabel.load(data_path1+'Brats18_2013_1_1/Brats18_2013_1_1_t1.nii').get_fdata() #Don't forget .get_fdata()
print(t1.shape)
plt.title('T1')
plt.imshow(t1[:,:,50], cmap='gray')

plt.subplot(2,3,2)
t1ce = nibabel.load(data_path1+'Brats18_2013_1_1/Brats18_2013_1_1_t1ce.nii').get_fdata() #Don't forget .get_fdata()
print(t1ce.shape)
plt.title('T1ce')
plt.imshow(t1ce[:,:,50], cmap='gray')

plt.subplot(2,3,3)
seg = nibabel.load(data_path1+'Brats18_2013_1_1/Brats18_2013_1_1_seg.nii').get_fdata() #Don't forget .get_fdata()
print(seg.shape)
plt.title('Seg')
plt.imshow(seg[:,:,50], cmap='gray')

plt.subplot(2,3,4)
flair = nibabel.load(data_path1+'Brats18_2013_1_1/Brats18_2013_1_1_flair.nii').get_fdata() #Don't forget .get_fdata()
print(flair.shape)
plt.title('FLAIR')
plt.imshow(flair[:,:,50], cmap='gray')

plt.subplot(2,3,5)
t2 = nibabel.load(data_path1+'Brats18_2013_1_1/Brats18_2013_1_1_t2.nii').get_fdata() #Don't forget .get_fdata()
print(t2.shape)
plt.title('T2')
plt.imshow(t2[:,:,50], cmap='gray')
# Out:
# (240, 240, 155)
# (240, 240, 155)
# (240, 240, 155)
# (240, 240, 155)
# (240, 240, 155)

# %%
data_path2 = 'D:/AI_Project/2021_training/'
folders2 = os.listdir(data_path2)

for folder2 in folders2:
    unfolder2 = data_path2 + folder2
    print(unfolder2)
# Out:
# D:/AI_Project/2021_training/BraTS2021_00000
# D:/AI_Project/2021_training/BraTS2021_00002
# D:/AI_Project/2021_training/BraTS2021_00003
# D:/AI_Project/2021_training/BraTS2021_00005
# D:/AI_Project/2021_training/BraTS2021_00006
# D:/AI_Project/2021_training/BraTS2021_00008
# D:/AI_Project/2021_training/BraTS2021_00009
# D:/AI_Project/2021_training/BraTS2021_00011
# D:/AI_Project/2021_training/BraTS2021_00012
# D:/AI_Project/2021_training/BraTS2021_00014
# D:/AI_Project/2021_training/BraTS2021_00016
# D:/AI_Project/2021_training/BraTS2021_00017
# D:/AI_Project/2021_training/BraTS2021_00018
# D:/AI_Project/2021_training/BraTS2021_00019
# D:/AI_Project/2021_training/BraTS2021_00020
# D:/AI_Project/2021_training/BraTS2021_00021
# D:/AI_Project/2021_training/BraTS2021_00022
# D:/AI_Project/2021_training/BraTS2021_00024
# D:/AI_Project/2021_training/BraTS2021_00025
# D:/AI_Project/2021_training/BraTS2021_00026
# D:/AI_Project/2021_training/BraTS2021_00028
# ...

# %%
#import unrar
#from unrar import rarfile

data_path2 = 'D:/AI_Project/2021_training/'
folders2 = os.listdir(data_path2)

for folder2 in folders2:
    unfolder2 = data_path2 + folder2
    list = os.listdir(unfolder2) 
    print(list)


#print("Conversion finished.")
# Out:
# ['BraTS2021_00000_flair.nii.gz', 'BraTS2021_00000_seg.nii.gz', 'BraTS2021_00000_t1.nii.gz', 'BraTS2021_00000_t1ce.nii.gz', 'BraTS2021_00000_t2.nii.gz']
# ['BraTS2021_00002_flair.nii.gz', 'BraTS2021_00002_seg.nii.gz', 'BraTS2021_00002_t1.nii.gz', 'BraTS2021_00002_t1ce.nii.gz', 'BraTS2021_00002_t2.nii.gz']
# ['BraTS2021_00003_flair.nii.gz', 'BraTS2021_00003_seg.nii.gz', 'BraTS2021_00003_t1.nii.gz', 'BraTS2021_00003_t1ce.nii.gz', 'BraTS2021_00003_t2.nii.gz']
# ['BraTS2021_00005_flair.nii.gz', 'BraTS2021_00005_seg.nii.gz', 'BraTS2021_00005_t1.nii.gz', 'BraTS2021_00005_t1ce.nii.gz', 'BraTS2021_00005_t2.nii.gz']
# ['BraTS2021_00006_flair.nii.gz', 'BraTS2021_00006_seg.nii.gz', 'BraTS2021_00006_t1.nii.gz', 'BraTS2021_00006_t1ce.nii.gz', 'BraTS2021_00006_t2.nii.gz']
# ['BraTS2021_00008_flair.nii.gz', 'BraTS2021_00008_seg.nii.gz', 'BraTS2021_00008_t1.nii.gz', 'BraTS2021_00008_t1ce.nii.gz', 'BraTS2021_00008_t2.nii.gz']
# ...

# %%
#Get folders list
data_path0 = 'D:/AI_Project/2021_training/'
folders0 = os.listdir(data_path0) 

# Traverse all the folders
for folder0 in folders0:
    dicom_folder0 = data_path0 + folder0
    nii_folder0 = data_path0 + 'nii_'+ folder0
    os.mkdir(nii_folder0) #Create folder to store the .nii files
    dicom2nifti.convert_directory(dicom_folder0, nii_folder0, compression= False) #Default compression= True
    print(folder0 + " has been converted.")

print("Conversion finished.")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_32560\2686715162.py in <module>
#       7     dicom_folder0 = data_path0 + folder0
#       8     nii_folder0 = data_path0 + 'nii_'+ folder0
# ----> 9     os.mkdir(nii_folder0) #Create folder to store the .nii files
#      10     dicom2nifti.convert_directory(dicom_folder0, nii_folder0, compression= False) #Default compression= True
#      11     print(folder0 + " has been converted.")
#
# FileExistsError: [WinError 183] 當檔案已存在時，無法建立該檔案。: 'D:/AI_Project/2021_training/nii_BraTS2021_00000'

# %%
#2021 dataset00495
plt.figure(figsize=(9,6))
plt.subplot(2,3,1)
t1 = nibabel.load(data_path0+'BraTS2021_00495/00000209_brain_t1.nii').get_fdata() #Don't forget .get_fdata()
print(t1.shape)
plt.title('T1')
plt.imshow(t1[:,:,100], cmap='gray')

plt.subplot(2,3,2)
t1ce = nibabel.load(data_path0+'BraTS2021_00495/00000209_brain_t1ce.nii').get_fdata() #Don't forget .get_fdata()
print(t1ce.shape)
plt.title('T1ce')
plt.imshow(t1ce[:,:,100], cmap='gray')

plt.subplot(2,3,3)
seg = nibabel.load(data_path0+'BraTS2021_00495/BraTS2021_00495_seg.nii').get_fdata() #Don't forget .get_fdata()
print(seg.shape)
plt.title('Seg')
plt.imshow(seg[:,:,100], cmap='gray')

plt.subplot(2,3,4)
flair = nibabel.load(data_path0+'BraTS2021_00495/00000209_brain_flair.nii').get_fdata() #Don't forget .get_fdata()
print(flair.shape)
plt.title('FLAIR')
plt.imshow(flair[:,:,100], cmap='gray')

plt.subplot(2,3,5)
t2 = nibabel.load(data_path0+'BraTS2021_00495/00000209_brain_t2.nii').get_fdata() #Don't forget .get_fdata()
print(t2.shape)
plt.title('T2')
plt.imshow(t2[:,:,100], cmap='gray')
# Out:
# (240, 240, 155)
# (240, 240, 155)
# (240, 240, 155)
# (240, 240, 155)
# (240, 240, 155)

# %%
#2021 dataset00621
plt.subplot(2,3,1)
t1 = nibabel.load(data_path0+'BraTS2021_00621/00000534_brain_t1.nii').get_fdata() #Don't forget .get_fdata()
print(t1.shape)
plt.title('T1')
plt.imshow(t1[:,:,100], cmap='gray')

plt.subplot(2,3,2)
t1ce = nibabel.load(data_path0+'BraTS2021_00621/00000534_brain_t1ce.nii').get_fdata() #Don't forget .get_fdata()
print(t1ce.shape)
plt.title('T1c')
plt.imshow(t1ce[:,:,100], cmap='gray')

plt.subplot(2,3,3)
seg = nibabel.load(data_path0+'BraTS2021_00621/BraTS2021_00621_seg.nii').get_fdata() #Don't forget .get_fdata()
print(seg.shape)
plt.title('Seg')
plt.imshow(seg[:,:,100], cmap='gray')

plt.subplot(2,3,4)
flair = nibabel.load(data_path0+'BraTS2021_00621/00000534_brain_flair.nii').get_fdata() #Don't forget .get_fdata()
print(flair.shape)
plt.title('FLAIR')
plt.imshow(flair[:,:,100], cmap='gray')

plt.subplot(2,3,5)
t2 = nibabel.load(data_path0+'BraTS2021_00621/00000534_brain_t2.nii').get_fdata() #Don't forget .get_fdata()
print(t2.shape)
plt.title('T2')
plt.imshow(t2[:,:,100], cmap='gray')
# Out:
# (240, 240, 155)
# (240, 240, 155)
# (240, 240, 155)
# (240, 240, 155)
# (240, 240, 155)

# %%
#2018 HGG
plt.subplot(2,5,1)
t1 = nibabel.load(data_path+'Brats18_2013_2_1/Brats18_2013_2_1_t1.nii').get_fdata() #Don't forget .get_fdata()
print(t1.shape)
plt.title('T1')
plt.imshow(t1[:,:,100], cmap='gray')

plt.subplot(2,5,2)
t1ce = nibabel.load(data_path+'Brats18_2013_2_1/Brats18_2013_2_1_t1ce.nii').get_fdata() #Don't forget .get_fdata()
print(t1ce.shape)
plt.title('T1ce')
plt.imshow(t1ce[:,:,100], cmap='gray')

plt.subplot(2,5,3)
seg = nibabel.load(data_path+'Brats18_2013_2_1/Brats18_2013_2_1_seg.nii').get_fdata() #Don't forget .get_fdata()
print(seg.shape)
plt.title('Seg')
plt.imshow(seg[:,:,100], cmap='gray')

plt.subplot(2,5,4)
flair = nibabel.load(data_path+'Brats18_2013_2_1/Brats18_2013_2_1_flair.nii').get_fdata() #Don't forget .get_fdata()
print(flair.shape)
plt.title('FLAIR')
plt.imshow(flair[:,:,100], cmap='gray')

plt.subplot(2,5,5)
t2 = nibabel.load(data_path+'Brats18_2013_2_1/Brats18_2013_2_1_t2.nii').get_fdata() #Don't forget .get_fdata()
print(t2.shape)
plt.title('T2')
plt.imshow(t2[:,:,100], cmap='gray')


#2021 dataset00495
plt.subplot(2,5,6)
t1 = nibabel.load(data_path0+'BraTS2021_00495/00000209_brain_t1.nii').get_fdata() #Don't forget .get_fdata()
print(t1.shape)
plt.title('T1')
plt.imshow(t1[:,:,100], cmap='gray')

plt.subplot(2,5,7)
t1ce = nibabel.load(data_path0+'BraTS2021_00495/00000209_brain_t1ce.nii').get_fdata() #Don't forget .get_fdata()
print(t1ce.shape)
plt.title('T1ce')
plt.imshow(t1ce[:,:,100], cmap='gray')

plt.subplot(2,5,8)
seg = nibabel.load(data_path0+'BraTS2021_00495/BraTS2021_00495_seg.nii').get_fdata() #Don't forget .get_fdata()
print(seg.shape)
plt.title('Seg')
plt.imshow(seg[:,:,100], cmap='gray')

plt.subplot(2,5,9)
flair = nibabel.load(data_path0+'BraTS2021_00495/00000209_brain_flair.nii').get_fdata() #Don't forget .get_fdata()
print(flair.shape)
plt.title('FLAIR')
plt.imshow(flair[:,:,100], cmap='gray')

plt.subplot(2,5,10)
t2 = nibabel.load(data_path0+'BraTS2021_00495/00000209_brain_t2.nii').get_fdata() #Don't forget .get_fdata()
print(t2.shape)
plt.title('T2')
plt.imshow(t2[:,:,100], cmap='gray')
# Out:
# (240, 240, 155)
# (240, 240, 155)
# (240, 240, 155)
# (240, 240, 155)
# (240, 240, 155)
# (240, 240, 155)
# (240, 240, 155)
# (240, 240, 155)
# (240, 240, 155)
# (240, 240, 155)
